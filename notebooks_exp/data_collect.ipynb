# %%
import os
os.chdir('/trinity/home/e.shvetsov/remotejup/llmlingua2/src')
print(os.getcwd())
# Out:
# /workspace/llmlingua2/src

# %%
# !mkdir -p results/meetingbank/origin results/qwen25_comp /workspace/hf_cache

# %%
os.environ['HF_DATASETS_CACHE'] = '/workspace/hf_cache'
os.environ['TRANSFORMERS_CACHE'] = '/workspace/hf_cache'
os.environ['HUGGINGFACE_HUB_CACHE'] = '/workspace/hf_cache'

# %%
# !sed -i 's|\.\./\.\./\.\./results|results|g' format_data.py

# %%
# !python format_data.py

# %%
# !python compress.py \
    --compressor qwen \
    --model_name Qwen/Qwen2.5-7B-Instruct \
    --load_origin_from results/meetingbank/origin/meetingbank_train_formated.json \
    --load_prompt_from compression_instructions.json \
    --prompt_id 4 \
    --chunk_size 256 \
    --n_max_new_token 256 \
    --save_path results/qwen25_comp/qwen_compressed.json
# Out:
# num data: 5169
# /opt/conda/lib/python3.11/site-packages/transformers/utils/hub.py:105: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# Loading Qwen2.5 model: Qwen/Qwen2.5-7B-Instruct...
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# ...
#   0%|                                                  | 0/5169 [00:00<?, ?it/s]0-th sample is processed
# 1-th sample is processed
# 2-th sample is processed
# 3-th sample is processed
# 4-th sample is processed
# 5-th sample is processed
# 6-th sample is processed
# 7-th sample is processed
# 8-th sample is processed
# 9-th sample is processed
# 10-th sample is processed
# 11-th sample is processed
# 12-th sample is processed
# 13-th sample is processed
# 14-th sample is processed
# 15-th sample is processed
# 16-th sample is processed
# 17-th sample is processed
# 18-th sample is processed
# ...
